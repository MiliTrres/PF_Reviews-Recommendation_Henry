# %%
import pandas as pd
import Utilidades as ut

# %%
df = pd.read_csv('../Datos/Archivos csv/metadatos-sitios.csv')

# %%
df.head(3)
# Out:
#    Unnamed: 0             name  \
# 0           0  Porter Pharmacy
# 1           1     City Textile
# 2           2     San Soo Dang
#
#                                              address  \
# 0  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
#
#                                  gmap_id description   latitude  longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8         NaN  32.388300  -83.35710
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9         NaN  34.018891 -118.21529
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49         NaN  34.058092 -118.29213
#
#                 category  avg_rating  num_of_reviews price  \
# 0           ['Pharmacy']         4.9              16   NaN
# 1   ['Textile exporter']         4.5               6   NaN
# 2  ['Korean restaurant']         4.4              18   NaN
#
#                                                hours  \
# 0  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM...
# 1                                                NaN
# 2  [['Thursday', '6:30AM–6PM'], ['Friday', '6:30A...
#
#                                                 MISC              state  \
# 0  {'Service options': ['In-store shopping', 'Sam...  Open ⋅ Closes 6PM
# 1                                                NaN           Open now
# 2  {'Service options': ['Takeout', 'Dine-in', 'De...  Open ⋅ Closes 6PM
#
#                                     relative_results  \
# 0  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x8...
# 1  ['0x80c2c624136ea88b:0xb0315367ed448771', '0x8...
# 2  ['0x80c2c78249aba68f:0x35bf16ce61be751d', '0x8...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...

# %% [markdown]
# Creamos una copia del DataFrame

# %%
df_copia = df.copy()

# %% [markdown]
# ***Filtramos el DataFrame, quedandonos con los registros relacionados al comercio y al estado de nuestro interes; McDonald's en Florida***
#
# Primero filtramos las filas que contengan el nombre McDonald's

# %%
df = df[df['name'].str.contains(r"\bMcDonald's\b|\bMc Donald's\b", case=False, na=False, regex=True)]

# %% [markdown]
# Ahora filtramos los McDdonald's ubicados en Florida mediante el zip code 32003 y 34997
#
# Fuente https://codigo-postal.co/eeuu/florida/

# %%
df = df[df['address'].str.extract(r"\b(32[0-9]{3}|33[0-9]{3}|34[0-9]{3}|349[0-7]{1})\b", expand=False).notnull()].copy()

# %% [markdown]
# Verificamos el nombre de los datos filtrados

# %%
df['name'].unique()
# Out:
# array(["McDonald's", "McDonald's / Ross's",
#        "McDonald's - NEW LOCATION (next to Walgreen's) NOW OPEN",
#        "Martin Brower/McDonald's Distribution Center"], dtype=object)

# %% [markdown]
# Se observa que hay varios nombres, los miramos a mas detalles para saber si son comida rapida

# %%
nombres = ["Martin Brower/McDonald's Distribution Center","McDonald's - NEW LOCATION (next to Walgreen's) NOW OPEN","McDonald's / Ross's"]
nombres_filtrado = df[df['name'].isin(nombres)]
nombres_filtrado
# Out:
#          Unnamed: 0                                               name  \
# 1391975     1391975                                McDonald's / Ross's
# 1553398     1553398  McDonald's - NEW LOCATION (next to Walgreen's)...
# 3006280     3006280       Martin Brower/McDonald's Distribution Center
#
#                                                    address  \
# 1391975  McDonald's / Ross's, 33507 MO-25, Advance, MO ...
# 1553398  McDonald's - NEW LOCATION (next to Walgreen's)...
# 3006280  Martin Brower/McDonald's Distribution Center, ...
#
#                                        gmap_id  \
# 1391975  0x88780f6b285dc8cf:0x216ca350f3e11727
# 1553398  0x88d8dff04035483b:0xd6795d19e9407ddc
# 3006280  0x88d902d94ebfb5e5:0x6ba01da2209293b8
#
#                                                description   latitude  \
# 1391975                                                NaN  37.104954
# 1553398  Classic, long-running fast-food chain known fo...  26.512142
# 3006280                                                NaN  26.250990
#
#          longitude                  category  avg_rating  num_of_reviews  \
# 1391975 -89.904044           ['Gas station']         3.0               4
# 1553398 -80.090973  ['Fast food restaurant']         3.5              28
# 3006280 -80.138780            ['Wholesaler']         3.7              28
#
#         price                                              hours  \
# 1391975   NaN                                                NaN
# 1553398     $  [['Monday', 'Open 24 hours'], ['Tuesday', 'Ope...
# 3006280   NaN  [['Saturday', 'Open 24 hours'], ['Sunday', 'Op...
#
#                                                       MISC          state  \
# 1391975  {'Accessibility': ['Wheelchair accessible entr...            NaN
# 1553398  {'Service options': ['Curbside pickup', 'No-co...  Open 24 hours
# 3006280  {'Accessibility': ['Wheelchair accessible entr...  Open 24 hours
#
#                                           relative_results  \
# 1391975  ['0x88780f1523a8e06f:0x4fd8c5ef7670fa7', '0x88...
# 1553398                                                NaN
# 3006280  ['0x88d91d0c82d408d1:0xb8074e2d66fc6879', '0x8...
#
#                                                        url
# 1391975  https://www.google.com/maps/place//data=!4m2!3...
# 1553398  https://www.google.com/maps/place//data=!4m2!3...
# 3006280  https://www.google.com/maps/place//data=!4m2!3...

# %% [markdown]
# Observamos que solo un local de los tres revisados tienen como categoría "Fast food". Procederemos a eliminar los otros que no pertecen a esta categoría

# %%
nombres = ["Martin Brower/McDonald's Distribution Center","McDonald's / Ross's"]
df = df[~df['name'].isin(nombres)]

# %% [markdown]
# Verificamos los tipos de datos y valores nulos

# %%
ut.tipo_dato(df)
# Out:
#              columna                         tipo_dato  porcentaje_nulos
# 0         Unnamed: 0                   [<class 'int'>]              0.00
# 1               name                   [<class 'str'>]              0.00
# 2            address                   [<class 'str'>]              0.00
# 3            gmap_id                   [<class 'str'>]              0.00
# 4        description  [<class 'str'>, <class 'float'>]              1.02
# 5           latitude                 [<class 'float'>]              0.00
# 6          longitude                 [<class 'float'>]              0.00
# 7           category                   [<class 'str'>]              0.00
# 8         avg_rating                 [<class 'float'>]              0.00
# 9     num_of_reviews                   [<class 'int'>]              0.00
# 10             price  [<class 'str'>, <class 'float'>]              2.04
# 11             hours  [<class 'float'>, <class 'str'>]             11.22
# 12              MISC                   [<class 'str'>]              0.00
# 13             state  [<class 'float'>, <class 'str'>]             11.22
# 14  relative_results  [<class 'str'>, <class 'float'>]              6.12
# 15               url                   [<class 'str'>]              0.00

# %% [markdown]
# La columna category no tiene el formato adecuado, hemos creado una funcion para normalizar la columna

# %%
df['category'].unique()
# Out:
# array(["['Fast food restaurant', 'Breakfast restaurant', 'Coffee shop', 'Hamburger restaurant', 'Ice cream shop', 'Restaurant', 'Salad shop', 'Sandwich shop']",
#        "['Fast food restaurant', 'Breakfast restaurant', 'Coffee shop', 'Hamburger restaurant', 'Restaurant', 'Sandwich shop']",
#        "['Fast food restaurant']",
#        "['Fast food restaurant', 'Breakfast restaurant', 'Hamburger restaurant', 'Restaurant']",
#        "['Fast food restaurant', 'Hamburger restaurant', 'Restaurant']",
#        "['Fast food restaurant', 'Breakfast restaurant', 'Coffee shop', 'Hamburger restaurant', 'Ice cream shop', 'Restaurant', 'Sandwich shop']"],
#       dtype=object)

# %%
df = ut.categoria_metadatos(df)
df.head(2)
# Out:
#         Unnamed: 0        name  \
# 276301      276301  McDonald's
# 317720      317720  McDonald's
#
#                                                   address  \
# 276301  McDonald's, 4704 Golden Gate Pkwy, Naples, FL ...
# 317720     McDonald's, 11542 US-19, Port Richey, FL 34668
#
#                                       gmap_id  \
# 276301  0x88db1d577dbd6dfb:0x5a0e01845200603f
# 317720  0x88c29af09988b085:0xa5b592ee878ed892
#
#                                               description   latitude  \
# 276301  Classic, long-running fast-food chain known fo...  26.182801
# 317720  Classic, long-running fast-food chain known fo...  28.325580
#
#         longitude                                           category  \
# 276301 -81.701932  Fast food restaurant, Breakfast restaurant, Co...
# 317720 -82.698588  Fast food restaurant, Breakfast restaurant, Co...
#
#         avg_rating  num_of_reviews price hours  \
# 276301         3.5             244     $   NaN
# 317720         3.4             158     $   NaN
#
#                                                      MISC state  \
# 276301  {'Service options': ['Outdoor seating', 'Drive...   NaN
# 317720  {'Service options': ['Drive-through', 'Deliver...   NaN
#
#                                          relative_results  \
# 276301  ['0x88dafd357c9a568d:0x103e6ced913d4fd9', '0x8...
# 317720                                                NaN
#
#                                                       url
# 276301  https://www.google.com/maps/place//data=!4m2!3...
# 317720  https://www.google.com/maps/place//data=!4m2!3...

# %% [markdown]
# Eliminamos columnas que no son relevantes

# %%
df = df.drop(columns=['Unnamed: 0','relative_results','price','MISC','hours'])

# %% [markdown]
# La columna description presenta dos tipos de clases ya que posee nulos

# %%
# Seleccionamos los valores nulos
valores_nulos = df[df['description'].isnull()]
valores_nulos
# Out:
#                name                                            address  \
# 2611607  McDonald's  McDonald's, 2263 Martin Luther King Jr Blvd, P...
#
#                                        gmap_id description   latitude  \
# 2611607  0x889383d78ec81547:0x18a1487ff62df2a0         NaN  30.189121
#
#          longitude                                           category  \
# 2611607 -85.650679  Fast food restaurant, Breakfast restaurant, Co...
#
#          avg_rating  num_of_reviews               state  \
# 2611607         4.2               5  Open ⋅ Closes 12AM
#
#                                                        url
# 2611607  https://www.google.com/maps/place//data=!4m2!3...

# %% [markdown]
# Reemplazamos valores nulos existentes

# %%
df[['description','category','state']] = df[['description','category','state']].fillna('Sin datos')
# Filtro por el valor 'Sin datos' para mostrar el resultado
df[df['description'] == 'Sin datos']
# Out:
#                name                                            address  \
# 2611607  McDonald's  McDonald's, 2263 Martin Luther King Jr Blvd, P...
#
#                                        gmap_id description   latitude  \
# 2611607  0x889383d78ec81547:0x18a1487ff62df2a0   Sin datos  30.189121
#
#          longitude                                           category  \
# 2611607 -85.650679  Fast food restaurant, Breakfast restaurant, Co...
#
#          avg_rating  num_of_reviews               state  \
# 2611607         4.2               5  Open ⋅ Closes 12AM
#
#                                                        url
# 2611607  https://www.google.com/maps/place//data=!4m2!3...

# %% [markdown]
# Renombramos la columna state, que hace referencia a la hora de apertura y cierre del local

# %%
df = df.rename(columns={'state':'open_closes'})

# %%
df
# Out:
#                name                                            address  \
# 276301   McDonald's  McDonald's, 4704 Golden Gate Pkwy, Naples, FL ...
# 317720   McDonald's     McDonald's, 11542 US-19, Port Richey, FL 34668
# 495251   McDonald's     McDonald's, 5420 Juliet Blvd, Naples, FL 34110
# 581635   McDonald's  McDonald's, 809 Lake Bradford Rd, Tallahassee,...
# 617778   McDonald's  McDonald's, 9303 Jeff Fuqua Blvd, Orlando, FL ...
# ...             ...                                                ...
# 2745183  McDonald's  McDonald's, 4878 N Kings Hwy, Fort Pierce, FL ...
# 2745218  McDonald's  McDonald's, 116 E State Rd 200, Yulee, FL 3209...
# 2745463  McDonald's  McDonald's, 1799 N Congress Ave, Boynton Beach...
# 2800228  McDonald's  McDonald's, 4860 E Irlo Bronson Memorial Hwy, ...
# 2991493  McDonald's  McDonald's, 6830 Normandy Blvd, Jacksonville, ...
#
#                                        gmap_id  \
# 276301   0x88db1d577dbd6dfb:0x5a0e01845200603f
# 317720   0x88c29af09988b085:0xa5b592ee878ed892
# 495251   0x88dae3d1695b90cf:0xbb720ec5fe038e22
# 581635   0x88ecf51a0a1ebe5b:0xd0ac298e268485be
# 617778   0x88e762e543b9ac13:0xbe247d28c5e48afc
# ...                                        ...
# 2745183  0x88def4681a72b87f:0x5226c64f7c1920bb
# 2745218  0x88e5a9d312c454ab:0xb45188da62367ada
# 2745463  0x88d8df5338c72e69:0x740c524b634d40be
# 2800228  0x88dd8d741fdd35f1:0xfc843d7c7f93b53b
# 2991493  0x88e5b8c338923433:0xd9e7a0e51cb221df
#
#                                                description   latitude  \
# 276301   Classic, long-running fast-food chain known fo...  26.182801
# 317720   Classic, long-running fast-food chain known fo...  28.325580
# 495251   Classic, long-running fast-food chain known fo...  26.270361
# 581635   Classic, long-running fast-food chain known fo...  30.433626
# 617778   Classic, long-running fast-food chain known fo...  28.432023
# ...                                                    ...        ...
# 2745183  Classic, long-running fast-food chain known fo...  27.521567
# 2745218  Classic, long-running fast-food chain known fo...  30.619993
# 2745463  Classic, long-running fast-food chain known fo...  26.544199
# 2800228  Classic, long-running fast-food chain known fo...  28.245453
# 2991493  Classic, long-running fast-food chain known fo...  30.301466
#
#          longitude                                           category  \
# 276301  -81.701932  Fast food restaurant, Breakfast restaurant, Co...
# 317720  -82.698588  Fast food restaurant, Breakfast restaurant, Co...
# 495251  -81.746178  Fast food restaurant, Breakfast restaurant, Co...
# 581635  -84.301441  Fast food restaurant, Breakfast restaurant, Co...
# 617778  -81.307359  Fast food restaurant, Breakfast restaurant, Co...
# ...            ...                                                ...
# 2745183 -80.397736  Fast food restaurant, Breakfast restaurant, Co...
# 2745218 -81.645345  Fast food restaurant, Breakfast restaurant, Co...
# 2745463 -80.091098  Fast food restaurant, Breakfast restaurant, Co...
# 2800228 -81.245003  Fast food restaurant, Breakfast restaurant, Co...
# 2991493 -81.758458  Fast food restaurant, Breakfast restaurant, Co...
#
#          avg_rating  num_of_reviews                         open_closes  \
# 276301          3.5             244                           Sin datos
# 317720          3.4             158                           Sin datos
# 495251          3.3             168                           Sin datos
# 581635          2.1             128                           Sin datos
# 617778          3.6             233                       Open 24 hours
# ...             ...             ...                                 ...
# 2745183         3.4             722                  Open ⋅ Closes 12AM
# 2745218         3.3            1471                  Open ⋅ Closes 12AM
# 2745463         3.8             762                       Open 24 hours
# 2800228         3.1             128  Closes soon ⋅ 12AM ⋅ Opens 5AM Tue
# 2991493         3.0              98                           Sin datos
#
#                                                        url
# 276301   https://www.google.com/maps/place//data=!4m2!3...
# 317720   https://www.google.com/maps/place//data=!4m2!3...
# 495251   https://www.google.com/maps/place//data=!4m2!3...
# 581635   https://www.google.com/maps/place//data=!4m2!3...
# 617778   https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 2745183  https://www.google.com/maps/place//data=!4m2!3...
# 2745218  https://www.google.com/maps/place//data=!4m2!3...
# 2745463  https://www.google.com/maps/place//data=!4m2!3...
# 2800228  https://www.google.com/maps/place//data=!4m2!3...
# 2991493  https://www.google.com/maps/place//data=!4m2!3...
#
# [98 rows x 11 columns]

# %%
ut.tipo_dato(df)
# Out:
#            columna          tipo_dato  porcentaje_nulos
# 0             name    [<class 'str'>]               0.0
# 1          address    [<class 'str'>]               0.0
# 2          gmap_id    [<class 'str'>]               0.0
# 3      description    [<class 'str'>]               0.0
# 4         latitude  [<class 'float'>]               0.0
# 5        longitude  [<class 'float'>]               0.0
# 6         category    [<class 'str'>]               0.0
# 7       avg_rating  [<class 'float'>]               0.0
# 8   num_of_reviews    [<class 'int'>]               0.0
# 9      open_closes    [<class 'str'>]               0.0
# 10             url    [<class 'str'>]               0.0
